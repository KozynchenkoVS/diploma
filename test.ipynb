# %%
import functools
import textwrap
from collections import OrderedDict

# %%
## QueryBuilder
class Query:
    keywords = [
        "SELECT",
        "CREATE TABLE IF NOT EXISTS",
        "INSERT INTO",
        "VALUES",
        "WHERE"
    ]
    separator = ','
    logic_separator = ' AND'
    _indent = functools.partial(textwrap.indent, prefix='')
    def __init__(self):
        self.data = OrderedDict([[k, []] for k in self.keywords])
    def clean_up(self, string : str):
        return textwrap.dedent(string.rstrip()).strip()
    def add(self, keyword, fields):
        target = self.data[keyword]
        if len(fields) == 0:
            target.append(self.clean_up('*'))
        else:
            for field in fields:
                target.append(self.clean_up(field))
        return self
    
    def __getattr__(self, name):
        if not name.isupper():
            return getattr(super(), name)
        return functools.partial(self.add, name.replace('_', ' '))

    def values_keyword(self, keyword, values):
        for i, value in enumerate(values, 1):
            last = i == len(values)
            yield self._indent(value)
            if not last:
                if keyword=="INSERT INTO":
                    yield " "
                    continue
                if keyword!='WHERE':
                    yield self.separator
                else: yield self.logic_separator
            yield ' '
    def keywords_put(self):
        for keyword, value in self.data.items():
            if not value:
                continue
            yield keyword + " "
            yield from self.values_keyword(keyword, value)
    def __str__(self):
        return ''.join(self.keywords_put())

# %%
fields = ('id', 'class')
string = '(' + ', '.join(fields) + ')'
string
# Out:
# '(id, class)'

# %%
def parse_values(values):
    return '(' + ', '.join(values) + ')'

# %%
def insert(table, fields, values):
    return str(Query().INSERT_INTO([table, parse_values(fields)]).VALUES([parse_values(values)]))

# %%
insert("aaa", ('id', 'class'), ('212', 'abba'))
# Out:
# 'INSERT INTO aaa (id, class) VALUES (212, abba) '

# %%
str(Query().INSERT_INTO(['table', '(id, class)']).VALUES(['(4, asd)']))
# Out:
# 'INSERT INTO table (id, class) VALUES (4, asd) '

# %%
import pandas as pd

pandas = pd.read_excel("BirdsFinal.xlsx")
pandas['id'] = pandas.index + 1

# %%
# Out:
#                          bird_en                        bird_ru  \
# 0               BANDED BROADBILL              Яванский рогоклюв
# 1              AUSTRAL CANASTERO                Южный канастеро
# 2                ARARIPE MANAKIN    Шлемоносный манакин-арарипе
# 3                    BAIKAL TEAL                  Чирок-клоктун
# 4                 ALBERTS TOWHEE                Чернолицый тохи
# ..                           ...                            ...
# 505                      WRENTIT           Американская тимелия
# 506  YELLOW BELLIED FLOWERPECKER            Желтобрюхий цветоед
# 507               YELLOW CACIQUE  Желтопоясничный чёрный кассик
# 508      YELLOW HEADED BLACKBIRD           Желтоголовый трупиал
# 509                   ZEBRA DOVE              Полосатая горлица
#
#                                                desc_en  \
# 0    The banded broadbill (Eurylaimus javanicus) is...
# 1    The austral canastero (Asthenes anthoides) is ...
# 2    The Araripe manakin (Antilophia bokermanni) is...
# 3    The Baikal teal (Sibirionetta formosa), also c...
# 4    Large, plain, long-tailed sparrow. Drab grayis...
# ..                                                 ...
# 505  The wrentit (Chamaea fasciata) is a small bird...
# 506  The yellow-bellied flowerpecker (Dicaeum melan...
# 507  The yellow-rumped cacique (Cacicus cela) is a ...
# 508  The yellow-headed blackbird (Xanthocephalus xa...
# 509  The zebra dove (Geopelia striata), also known ...
#
#                                                desc_ru  \
# 0    Яванский рогоклюв (лат. Eurylaimus javanicus) ...
# 1    Австралийский канастеро ( Asthenes anthoides )...
# 2    Шлемоносный манакин-арарипе (лат. Antilophia b...
# 3    Чирок-клоктун, или клоктун (лат. Sibirionetta ...
# 4    Большой, простой, длиннохвостый воробей. Весь ...
# ..                                                 ...
# 505  Америка́нская тиме́лия, или крапи́вниковая син...
# 506  Желтобрюхий цветоед (лат. Dicaeum melanoxanthu...
# 507  Желтопоясничный чёрный кассик (лат. Cacicus ce...
# 508  Желтоголовый трупиал (лат. Xanthocephalus xant...
# 509  Полоса́тая го́рлица, или зе́бровая полоса́тая ...
#
#                                               place_ru  \
# 0    Вид распространён в Юго-Восточной Азии. Встреч...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 505                                                NaN
# 506                                                NaN
# 507                                                NaN
# 508                                                NaN
# 509                                                NaN
#
#                                               place_en  \
# 0    Mainland Southeast Asia and the Greater Sunda ...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 505                                                NaN
# 506                                                NaN
# 507                                                NaN
# 508                                                NaN
# 509                                                NaN
#
#                                                size_ru  \
# 0    Птица достигает длины 21,5—23 см. Тело крепкое...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 505                                                NaN
# 506                                                NaN
# 507                                                NaN
# 508                                                NaN
# 509                                                NaN
#
#                                                size_en   id
# 0    A striking, large-bodied bird with a length of...    1
# 1                                                  NaN    2
# 2                                                  NaN    3
# 3                                                  NaN    4
# 4                                                  NaN    5
# ..                                                 ...  ...
# 505                                                NaN  506
# 506                                                NaN  507
# 507                                                NaN  508
# 508                                                NaN  509
# 509                                                NaN  510
#
# [510 rows x 9 columns]
